# %%
import pandas as pd

# %%
df = pd.read_csv('war_daily_bat.csv')

# %%
df.sample(10)
# Out:
#             name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 13509   Fred Bruckbauer  23.0  111616.0  bruckfr01     1961     MIN         1
# 43988        Sammy Hale  24.0  115329.0   halesa01     1921     DET         1
# 103329      Hal Spindel  26.0  122600.0  spindha01     1939     SLB         1
# 43513        Tony Gwynn  36.0  115270.0  gwynnto01     1996     SDP         1
# 55408        Cobe Jones  23.0  116675.0  jonesco02     1929     PIT         1
# 67845     Rube Marshall  21.0  118322.0  marshru01     1912     PHI         1
# 64442    George Lombard  22.0  136601.0  lombage01     1998     ATL         1
# 15559    Miguel Cabrera  36.0  408234.0  cabremi01     2019     DET         1
# 40471   Marwin Gonzalez  33.0  503556.0  gonzama01     2022     NYY         1
# 114569      Buck Washer  22.0  123961.0  washebu01     1905     PHI         1
#
#        lg_ID     PA    G  ...  oppRpG_rep  pyth_exponent  pyth_exponent_rep  \
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# name_common
# age
# mlb_ID
# player_ID
# year_ID
# team_ID
# stint_ID
# lg_ID
# PA
# G
# Inn
# runs_bat
# runs_br
# runs_dp
# runs_field
# runs_infield
# runs_outfield
# runs_catcher
# runs_good_plays
# runs_defense
# runs_position
# runs_position_p
# runs_replacement
# runs_above_rep
# runs_above_avg
# runs_above_avg_off
# runs_above_avg_def
# WAA
# WAA_off
# WAA_def
# WAR
# WAR_def
# WAR_off
# WAR_rep
# salary
# pitcher
# teamRpG
# oppRpG
# oppRpPA_rep
# oppRpG_rep
# pyth_exponent
# pyth_exponent_rep
# waa_win_perc
# waa_win_perc_off
# waa_win_perc_def
# waa_win_perc_rep
# OPS_plus
# TOB_lg
# TB_lg

# %%
df[['name_common', 'WAR']].sample(10)
# Out:
#              name_common   WAR
# 24921       Bill Dammann -0.17
# 85427      Jace Peterson -1.03
# 11133         Jack Boyle -1.78
# 71314       Ryan McGuire  0.11
# 106331     Jack Sutthoff -0.04
# 97374   Nate Schierholtz  0.45
# 12422       Doug Brocail  0.00
# 97287    Frank Scheibeck -0.17
# 49924      Aaron Holbert -0.09
# 118744       Nip Winters  0.93

# %%
df.count()
# Out:
# name_common           121375
# age                   119987
# mlb_ID                112987
# player_ID             121375
# year_ID               121375
# team_ID               121375
# stint_ID              121375
# lg_ID                 120639
# PA                    120573
# G                     121375
# Inn                    76467
# runs_bat              121375
# runs_br               121375
# runs_dp               121375
# runs_field            121375
# runs_infield           76467
# runs_outfield          76467
# runs_catcher           76467
# runs_good_plays        29475
# runs_defense          121375
# runs_position         120387
# runs_position_p       121374
# runs_replacement      120573
# runs_above_rep        120387
# runs_above_avg        120387
# runs_above_avg_off    120387
# runs_above_avg_def    120387
# WAA                   111706
# WAA_off               111706
# WAA_def               111706
# WAR                   110563
# WAR_def               111706
# ...

# %%
df.loc[df['name_common'] == 'Aaron Judge'][['mlb_ID','player_ID', 'year_ID','name_common','team_ID','salary','pitcher','WAR']]
# Out:
#          mlb_ID  player_ID  year_ID  name_common team_ID      salary pitcher  \
# 56166  592450.0  judgeaa01     2016  Aaron Judge     NYY         NaN       N
# 56167  592450.0  judgeaa01     2017  Aaron Judge     NYY    544500.0       N
# 56168  592450.0  judgeaa01     2018  Aaron Judge     NYY    622300.0       N
# 56169  592450.0  judgeaa01     2019  Aaron Judge     NYY    684300.0       N
# 56170  592450.0  judgeaa01     2020  Aaron Judge     NYY   8500000.0       N
# 56171  592450.0  judgeaa01     2021  Aaron Judge     NYY  10175000.0       N
# 56172  592450.0  judgeaa01     2022  Aaron Judge     NYY  19000000.0       N
# 56173  592450.0  judgeaa01     2023  Aaron Judge     NYY  40000000.0       N
#
#          WAR
# 56166  -0.29
# 56167   7.99
# 56168   5.87
# 56169   5.61
# 56170   1.14
# 56171   6.07
# 56172  10.60
# 56173   2.31

# %%
df['year_ID'].max() - df['year_ID'].min()
# Out:
# 152
